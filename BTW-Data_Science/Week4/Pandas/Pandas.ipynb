# %% [markdown]
# ### Pandas

# %% [markdown]
# ##### Installation and Loading Data

# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv")
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
# percentage of missing values in each columns
df.isnull().sum()/df.shape[0] * 100
# Out:
# ResponseId              0.000000
# MainBranch              0.000000
# Employment              2.127805
# RemoteWork             19.531037
# CodingActivities       19.611563
#                          ...
# TrueFalse_2            51.254299
# TrueFalse_3            51.207894
# SurveyLength            3.854343
# SurveyEase              3.766992
# ConvertedCompYearly    48.038707
# Length: 79, dtype: float64

# %%
# to see all columns
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
# to see all columns
pd.set_option('display.max_rows',None)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6  I am not primarily a developer, but I write co...
# 6           7                        I code primarily as a hobby
# 7           8                     I am a developer by profession
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# ...

# %% [markdown]
# ### DataFrame and Series Basics - Selecting Rows and Columns

# %%
people = {
    "first" : "Sahil",
    "last" : "Jatoi",
    "Email" : "Sahiljatoi744@gmail.com"
}

# %%
people = {
    "first" : ["Sahil"],
    "last" : ["Jatoi"],
    "Email" : ["Sahiljatoi744@gmail.com"]
}

# %%
people = {
    "first" : ["Sahil","Roodie","Rabbit"],
    "last" : ["Jatoi","Jatoi","Jatoi"],
    "Email" : ["Sahiljatoi744@gmail.com","RoodieJatoi744@gmail.com","RabbitJatoi744@gmail.com"]
}

# %%
people['Email']
# Out:
# ['Sahiljatoi744@gmail.com',
#  'RoodieJatoi744@gmail.com',
#  'RabbitJatoi744@gmail.com']

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(people)
df1
# Out:
#     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df1['Email']
# Out:
# 0     Sahiljatoi744@gmail.com
# 1    RoodieJatoi744@gmail.com
# 2    RabbitJatoi744@gmail.com
# Name: Email, dtype: object

# %%
type(df1['Email'])
# Out:
# pandas.core.series.Series

# %%
df1.count
# Out:
# <bound method DataFrame.count of     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2  Rabbit  Jatoi  RabbitJatoi744@gmail.com>

# %%
# access multiple columns

# %%
df1[['last','Email']]
# Out:
#     last                     Email
# 0  Jatoi   Sahiljatoi744@gmail.com
# 1  Jatoi  RoodieJatoi744@gmail.com
# 2  Jatoi  RabbitJatoi744@gmail.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'Email'], dtype='object')

# %%
df1.iloc[0]
# Out:
# first                      Sahil
# last                       Jatoi
# Email    Sahiljatoi744@gmail.com
# Name: 0, dtype: object

# %%
df1.iloc[[0,1]]
# Out:
#     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com

# %%
df1.iloc[[0,1],2]
# Out:
# 0     Sahiljatoi744@gmail.com
# 1    RoodieJatoi744@gmail.com
# Name: Email, dtype: object

# %%
df1
# Out:
#     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df1.loc[[0,1]]
# Out:
#     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com

# %%
df1.loc[[0,1],['Email','last']]
# Out:
#                       Email   last
# 0   Sahiljatoi744@gmail.com  Jatoi
# 1  RoodieJatoi744@gmail.com  Jatoi

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['DatabaseWantToWorkWith'].value_counts()
# Out:
# PostgreSQL                                                                                           3994
# Microsoft SQL Server                                                                                 2025
# MongoDB                                                                                              1850
# MySQL                                                                                                1806
# SQLite                                                                                               1532
#                                                                                                      ...
# Cloud Firestore;IBM DB2;MongoDB;PostgreSQL;Redis                                                        1
# Couchbase;MongoDB;Oracle;PostgreSQL                                                                     1
# Cassandra;DynamoDB;Elasticsearch;MariaDB;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;Redis            1
# ...

# %%
df.loc[[0,1,2],'DatabaseWantToWorkWith']
# Out:
# 0                     NaN
# 1                     NaN
# 2    Microsoft SQL Server
# Name: DatabaseWantToWorkWith, dtype: object

# %%
df.loc[0:2,'DatabaseWantToWorkWith']
# Out:
# 0                     NaN
# 1                     NaN
# 2    Microsoft SQL Server
# Name: DatabaseWantToWorkWith, dtype: object

# %% [markdown]
# #### Set, Reset, and Use Indexes

# %%
df1.set_index('Email')
# Out:
#                            first   last
# Email
# Sahiljatoi744@gmail.com    Sahil  Jatoi
# RoodieJatoi744@gmail.com  Roodie  Jatoi
# RabbitJatoi744@gmail.com  Rabbit  Jatoi

# %%
df1
# Out:
#     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df.index
# Out:
# RangeIndex(start=0, stop=73268, step=1)

# %%
df1.loc[0]
# Out:
# first                      Sahil
# last                       Jatoi
# Email    Sahiljatoi744@gmail.com
# Name: 0, dtype: object

# %%
df1.reset_index(inplace=True)
df1
# Out:
#    index   first   last                     Email
# 0      0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1      1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2      2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %% [markdown]
# #### Using Conditionals to Filter Rows and Columns

# %%
df1['last'] == 'Jatoi'
# Out:
# 0    True
# 1    True
# 2    True
# Name: last, dtype: bool

# %%
filt = (df1['last'] == 'Jatoi')

# %%
df1[filt]
# Out:
#    index   first   last                     Email
# 0      0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1      1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2      2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df1.loc[filt, 'Email']
# Out:
# 0     Sahiljatoi744@gmail.com
# 1    RoodieJatoi744@gmail.com
# 2    RabbitJatoi744@gmail.com
# Name: Email, dtype: object

# %%
# ~ means not
df1.loc[~filt, 'Email']
# Out:
# Series([], Name: Email, dtype: object)

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageHaveWorkedWith']
# Out:
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 6            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 11       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 14             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 16                                    C#;Java;PHP;Python;R
#                                ...
# 73257                                         C;Python;SQL
# 73261    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object

# %%
df.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 2               3  I am not primarily a developer, but I write co...
# 6               7                        I code primarily as a hobby
# 11             12  I am not primarily a developer, but I write co...
# 14             15                     I am a developer by profession
# 16             17                     I am a developer by profession
# ...           ...                                                ...
# 73257       73258                              I am learning to code
# 73261       73262                     I am a developer by profession
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
#
#                                               Employment  \
# 2                                    Employed, full-time
# ...

# %% [markdown]
# #### Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df1.columns
# Out:
# Index(['index', 'first', 'last', 'Email'], dtype='object')

# %%
df1.columns = ['index','first_name','last_name','email']

# %%
df1
# Out:
#    index first_name last_name                     email
# 0      0      Sahil     Jatoi   Sahiljatoi744@gmail.com
# 1      1     Roodie     Jatoi  RoodieJatoi744@gmail.com
# 2      2     Rabbit     Jatoi  RabbitJatoi744@gmail.com

# %%
df1.columns = df1.columns.str.replace('_',' ')
df1
# Out:
#    index first name last name                     email
# 0      0      Sahil     Jatoi   Sahiljatoi744@gmail.com
# 1      1     Roodie     Jatoi  RoodieJatoi744@gmail.com
# 2      2     Rabbit     Jatoi  RabbitJatoi744@gmail.com

# %%
df1.columns = df1.columns.str.replace(' ','_')
df1
# Out:
#    index first_name last_name                     email
# 0      0      Sahil     Jatoi   Sahiljatoi744@gmail.com
# 1      1     Roodie     Jatoi  RoodieJatoi744@gmail.com
# 2      2     Rabbit     Jatoi  RabbitJatoi744@gmail.com

# %%
df1.columns = [x.lower() for x in df1.columns]
df1
# Out:
#    index first_name last_name                     email
# 0      0      Sahil     Jatoi   Sahiljatoi744@gmail.com
# 1      1     Roodie     Jatoi  RoodieJatoi744@gmail.com
# 2      2     Rabbit     Jatoi  RabbitJatoi744@gmail.com

# %%
df1.rename(columns={'first_name':'first','last_name':'last'}, inplace=True)
df1
# Out:
#    index   first   last                     email
# 0      0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1      1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2      2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df1.loc[2] = ['2','Rabbit','Jatoi','RabbitJatoi744@gmail.com']

# %%
df1
# Out:
#   index   first   last                     email
# 0     0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1     1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2     2  Rabbit  Jatoi  RabbitJatoi744@gmail.com

# %%
df1.loc[2, 'last'] = 'smith'
df1
# Out:
#   index   first   last                     email
# 0     0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1     1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2     2  Rabbit  smith  RabbitJatoi744@gmail.com

# %%
filt = (df1['email'] == 'Sahiljatoi744@gmail.com')
df1[filt]['last'] = 'jatoi'
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\3104083646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[filt]['last'] = 'jatoi'

# %%
df1
# Out:
#   index   first   last                     email
# 0     0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1     1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2     2  Rabbit  smith  RabbitJatoi744@gmail.com

# %%
filt = (df1['email'] == 'Sahiljatoi744@gmail.com')
df1.loc[filt, 'last'] = 'jatoi'

# %%
df1
# Out:
#   index   first   last                     email
# 0     0   Sahil  jatoi   Sahiljatoi744@gmail.com
# 1     1  Roodie  Jatoi  RoodieJatoi744@gmail.com
# 2     2  Rabbit  smith  RabbitJatoi744@gmail.com

# %%
df1['email'] = df1['email'].str.lower()
df1
# Out:
#   index   first   last                     email
# 0     0   Sahil  jatoi   sahiljatoi744@gmail.com
# 1     1  Roodie  Jatoi  roodiejatoi744@gmail.com
# 2     2  Rabbit  smith  rabbitjatoi744@gmail.com

# %%
df1['email'].apply(len)
# Out:
# 0    23
# 1    24
# 2    24
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df1['email'].apply(update_email)
# Out:
# 0     SAHILJATOI744@GMAIL.COM
# 1    ROODIEJATOI744@GMAIL.COM
# 2    RABBITJATOI744@GMAIL.COM
# Name: email, dtype: object

# %%
df1['email'].apply(lambda x: x.lower())
# Out:
# 0     sahiljatoi744@gmail.com
# 1    roodiejatoi744@gmail.com
# 2    rabbitjatoi744@gmail.com
# Name: email, dtype: object

# %%
df1.apply(len, axis='columns')
# Out:
# 0    4
# 1    4
# 2    4
# dtype: int64

# %%
df1.apply(len, axis='rows')
# Out:
# index    3
# first    3
# last     3
# email    3
# dtype: int64

# %%
df1['first'].map({'Sahil':'Roodie'})
# Out:
# 0    Roodie
# 1       NaN
# 2       NaN
# Name: first, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.rename(columns={'LanguageHaveWorkedWith':'Programming_Languages'},inplace=True)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %% [markdown]
# #### Add/Remove Rows and Columns From DataFrames

# %%
df1['first'] + ' ' + df1['last']
# Out:
# 0     Sahil jatoi
# 1    Roodie Jatoi
# 2    Rabbit smith
# dtype: object

# %%
df1['full_name'] = df1['first'] + ' ' + df1['last']
df1
# Out:
#   index   first   last                     email     full_name
# 0     0   Sahil  jatoi   sahiljatoi744@gmail.com   Sahil jatoi
# 1     1  Roodie  Jatoi  roodiejatoi744@gmail.com  Roodie Jatoi
# 2     2  Rabbit  smith  rabbitjatoi744@gmail.com  Rabbit smith

# %%
df1.drop(columns=['first','last'], inplace=True)
df1
# Out:
#   index                     email     full_name
# 0     0   sahiljatoi744@gmail.com   Sahil jatoi
# 1     1  roodiejatoi744@gmail.com  Roodie Jatoi
# 2     2  rabbitjatoi744@gmail.com  Rabbit smith

# %%
df1['full_name'].str.split(' ',expand=True)
df1
# Out:
#   index                     email     full_name
# 0     0   sahiljatoi744@gmail.com   Sahil jatoi
# 1     1  roodiejatoi744@gmail.com  Roodie Jatoi
# 2     2  rabbitjatoi744@gmail.com  Rabbit smith

# %%
df1[['first','last']] = df1['full_name'].str.split(' ',expand=True)
df1
# Out:
#   index                     email     full_name   first   last
# 0     0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1     1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2     2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1.drop(columns='index',inplace=True)

# %%
df1.append({'first':'Ahmed'}, ignore_index=True)
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\3377118951.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append({'first':'Ahmed'}, ignore_index=True)
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith
# 3                       NaN           NaN   Ahmed    NaN

# %%
people = {
    "first" : ["Sahil","Roodie"],
    "last" : ["Jatoi","Jatoi"],
    "Email" : ["Sahiljatoi744@gmail.com","RoodieJatoi744@gmail.com"]
}
df2 = pd.DataFrame(people)
df2
# Out:
#     first   last                     Email
# 0   Sahil  Jatoi   Sahiljatoi744@gmail.com
# 1  Roodie  Jatoi  RoodieJatoi744@gmail.com

# %%
df1.append(df2,ignore_index=True)
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\2717680053.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2,ignore_index=True)
#                       email     full_name   first   last  \
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith
# 3                       NaN           NaN   Sahil  Jatoi
# 4                       NaN           NaN  Roodie  Jatoi
#
#                       Email
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3   Sahiljatoi744@gmail.com
# 4  RoodieJatoi744@gmail.com

# %%
df1.drop(index=2)
# Out:
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi

# %%
filt = df1['last'] == 'jatoi'
df1.drop(index=df1[filt].index)
# Out:
#                       email     full_name   first   last
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %% [markdown]
# #### Sorting Data

# %%
df1.sort_values(by='last')
# Out:
#                       email     full_name   first   last
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1.sort_values(by='last',ascending=False)
# Out:
#                       email     full_name   first   last
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi

# %%
df1.sort_values(by=['last','first'],ascending=False)
# Out:
#                       email     full_name   first   last
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi

# %%
df1.sort_values(by=['last','first'],ascending=[False, True])
# Out:
#                       email     full_name   first   last
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi

# %%
df1.sort_index()
# Out:
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1['last'].sort_values()
# Out:
# 1    Jatoi
# 0    jatoi
# 2    smith
# Name: last, dtype: object

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country']
# Out:
# 51188    Afghanistan
# 38512    Afghanistan
# 7944     Afghanistan
# 29704    Afghanistan
# 19201    Afghanistan
#             ...
# 73109            NaN
# 73157            NaN
# 73201            NaN
# 73215            NaN
# 73243            NaN
# Name: Country, Length: 73268, dtype: object

# %% [markdown]
# #### Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# 51188         NaN
# 38512    158484.0
# 7944          NaN
# 29704         NaN
# 19201         NaN
# 24812         NaN
# 56355         NaN
# 2737          NaN
# 56266         NaN
# 56188         NaN
# 69586         NaN
# 2448      10894.0
# 5464          NaN
# 43690     13212.0
# 30040         NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 67845.0

# %%
df.median()
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# ResponseId                   36634.5
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df['ConvertedCompYearly'].count()
# Out:
# 38071

# %%
df['ConvertedCompYearly'].value_counts()
# Out:
# 150000.0    393
# 200000.0    362
# 120000.0    341
# 63986.0     304
# 100000.0    279
#            ...
# 34270.0       1
# 1963.0        1
# 21845.0       1
# 9180.0        1
# 568968.0      1
# Name: ConvertedCompYearly, Length: 7909, dtype: int64

# %%
schema_df['qname'].head(79)
# Out:
# 0              S0
# 1        MetaInfo
# 2              S1
# 3      MainBranch
# 4      Employment
#          ...
# 74    Frequency_2
# 75    Frequency_3
# 76    TrueFalse_1
# 77    TrueFalse_2
# 78    TrueFalse_3
# Name: qname, Length: 79, dtype: object

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
df['MainBranch'].value_counts(normalize=True)
# Out:
# I am a developer by profession                                                   0.730292
# I am learning to code                                                            0.086109
# I am not primarily a developer, but I write code sometimes as part of my work    0.079080
# I code primarily as a hobby                                                      0.066400
# None of these                                                                    0.020432
# I used to be a developer by profession, but no longer am                         0.017688
# Name: MainBranch, dtype: float64

# %%
df['Employment'].value_counts()
# Out:
# Employed, full-time                                                                                                                                                              42962
# Student, full-time                                                                                                                                                                6756
# Independent contractor, freelancer, or self-employed                                                                                                                              4978
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                          3486
# Not employed, but looking for work                                                                                                                                                1831
# ...

# %%
typegroup = df.groupby(['MainBranch'])

# %%
typegroup.get_group('I am a developer by profession')
# Out:
#        ResponseId                      MainBranch  \
# 38512       38513  I am a developer by profession
# 19201       19202  I am a developer by profession
# 24812       24813  I am a developer by profession
# 56355       56356  I am a developer by profession
# 2737         2738  I am a developer by profession
# ...           ...                             ...
# 31002       31003  I am a developer by profession
# 46672       46673  I am a developer by profession
# 71357       71358  I am a developer by profession
# 19593       19594  I am a developer by profession
# 46151       46152  I am a developer by profession
#
#                                               Employment  \
# 38512                                Employed, full-time
# 19201  Student, full-time;Not employed, but looking f...
# 24812                                Employed, full-time
# 56355                                Employed, full-time
# 2737                                 Employed, full-time
# ...

# %%
filt = df['MainBranch'] == 'I am a developer by profession'
df.loc[filt]
# Out:
#        ResponseId                      MainBranch  \
# 38512       38513  I am a developer by profession
# 19201       19202  I am a developer by profession
# 24812       24813  I am a developer by profession
# 56355       56356  I am a developer by profession
# 2737         2738  I am a developer by profession
# ...           ...                             ...
# 31002       31003  I am a developer by profession
# 46672       46673  I am a developer by profession
# 71357       71358  I am a developer by profession
# 19593       19594  I am a developer by profession
# 46151       46152  I am a developer by profession
#
#                                               Employment  \
# 38512                                Employed, full-time
# 19201  Student, full-time;Not employed, but looking f...
# 24812                                Employed, full-time
# 56355                                Employed, full-time
# 2737                                 Employed, full-time
# ...

# %%
typegroup['Employment'].value_counts()
# Out:
# MainBranch                                                Employment
# I am a developer by profession                            Employed, full-time                                                                                                              37733
#                                                           Independent contractor, freelancer, or self-employed                                                                              4151
#                                                           Employed, full-time;Independent contractor, freelancer, or self-employed                                                          3180
#                                                           Student, full-time                                                                                                                1225
# ...

# %%
typegroup['WorkExp'].value_counts()
# Out:
# MainBranch                                                WorkExp
# I am a developer by profession                            5.0        2816
#                                                           3.0        2666
#                                                           4.0        2516
#                                                           2.0        2426
#                                                           1.0        2230
#                                                                      ...
# I used to be a developer by profession, but no longer am  44.0          1
#                                                           45.0          1
#                                                           47.0          1
#                                                           48.0          1
#                                                           50.0          1
# Name: WorkExp, Length: 216, dtype: int64

# %%
typegroup['WorkExp'].agg(['median','mean'])
# Out:
#                                                     median       mean
# MainBranch
# I am a developer by profession                         7.0   9.975920
# I am learning to code                                  4.0   6.740437
# I am not primarily a developer, but I write cod...    10.0  12.919398
# I code primarily as a hobby                            7.5  11.036458
# I used to be a developer by profession, but no ...    15.0  16.542797
# None of these                                          NaN        NaN

# %%
filt = df['MainBranch'] == 'I am a developer by profession'
df[filt]['Programming_Languages'].str.contains('Python').sum()
# Out:
# 23201

# %%
typegroup['Programming_Languages'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# MainBranch
# I am a developer by profession                                                   23201
# I am learning to code                                                             3469
# I am not primarily a developer, but I write code sometimes as part of my work     3740
# I code primarily as a hobby                                                       3184
# I used to be a developer by profession, but no longer am                           561
# None of these                                                                        0
# Name: Programming_Languages, dtype: int64

# %% [markdown]
# #### Casting Datatypes and Handling Missing Values

# %%
df1.dropna()
# Out:
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1.dropna(axis='index',how='any')
# Out:
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1.dropna(axis='index',how='any',subset=['email'])
# Out:
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1.dropna(axis='index',how='all',subset=['email'])
# Out:
#                       email     full_name   first   last
# 0   sahiljatoi744@gmail.com   Sahil jatoi   Sahil  jatoi
# 1  roodiejatoi744@gmail.com  Roodie Jatoi  Roodie  Jatoi
# 2  rabbitjatoi744@gmail.com  Rabbit smith  Rabbit  smith

# %%
df1.isna()
# Out:
#    email  full_name  first   last
# 0  False      False  False  False
# 1  False      False  False  False
# 2  False      False  False  False

# %%
df1.dtypes
# Out:
# email        object
# full_name    object
# first        object
# last         object
# dtype: object

# %%
df1['first'].astype('string')
# Out:
# 0     Sahil
# 1    Roodie
# 2    Rabbit
# Name: first, dtype: string

# %%
df['YearsCode'].head(10)
# Out:
# 51188                  21
# 38512                  40
# 7944                    2
# 29704                   1
# 19201                 NaN
# 24812                  17
# 56355                   4
# 2737                   17
# 56266                  28
# 56188    Less than 1 year
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['21', '40', '2', '1', nan, '17', '4', '28', 'Less than 1 year',
#        '15', '8', '12', '10', '18', '20', '3', '9', '41', '5', '6',
#        'More than 50 years', '14', '25', '7', '50', '49', '13', '11',
#        '30', '27', '22', '19', '16', '33', '24', '26', '23', '31', '32',
#        '35', '29', '42', '36', '34', '37', '38', '43', '48', '45', '44',
#        '39', '47', '46'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.251307285752338

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# #### Working with Dates and Time Series Data

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df3 = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
df3
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\3330117849.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# ...

# %%
#df3['Date'] = pd.to_datetime(df3['Date'], format='%Y-%m-%d %I-%p')

# %%
df3['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df3['DayOfWeek'] = df3['Date'].dt.day_name()
df3
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df3['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df3['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df3['Date'].max() - df3['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df3['Date'] > '2020')
df3.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1743 2020-01-01 05:00:00  ETHUSD  129.56  129.94  129.47  129.83   232163.70
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt = ((df3['Date'] >= '2019') & (df3['Date'] < '2020'))
df3.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
filt = ((df3['Date'] >= pd.to_datetime('2019-01-01')))
df3.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df3.set_index('Date',inplace=True)
df3
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df3['2019']
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\3359826300.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df3['2019']
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# ...

# %%
df3['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df3['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df3['2020-01-01']['High'].max()
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\761621772.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df3['2020-01-01']['High'].max()
# 132.68

# %%
highs = df3['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
import matplotlib.pyplot as plt
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df3.resample('W').mean()
# Out:
# C:\Users\H S COMPUTER S HYD\AppData\Local\Temp\ipykernel_18284\1045342694.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.resample('W').mean()
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# ...

# %%
df3.resample('W').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
